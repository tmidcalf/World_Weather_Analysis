# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | saint george
# Processing Record 5 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 1 | sioux lookout
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | ontario
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | lira
# Processing Record 14 of Set 1 | waipawa
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | isangel
# Processing Record 23 of Set 1 | norman wells
# Processing Record 24 of Set 1 | castanos
# Processing Record 25 of Set 1 | zyryanka
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | los llanos de aridane
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | halifax
# Processing Record 30 of Set 1 | natal
# Processing Record 31 of Set 1 | nishihara
# Processing Record 32 of Set 1 | kailua
# Processing Record 33 of Set 1 | jiuquan
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | berlevag
# Processing Record 37 of Set 1 | capreol
# Processing Record 38 of Set 1 | ishigaki
# Processing Record 39 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 1 | lisakovsk
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | aranos
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | bosaso
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 1 | amahai
# Processing Record 50 of Set 1 | ipora
# Processing Record 1 of Set 2 | moss vale
# Processing Record 2 of Set 2 | zhigansk
# Processing Record 3 of Set 2 | leningradskiy
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 2 | nagato
# Processing Record 8 of Set 2 | vanavara
# Processing Record 9 of Set 2 | madalag
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | pacific grove
# Processing Record 13 of Set 2 | cidreira
# Processing Record 14 of Set 2 | faya
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | nome
# Processing Record 18 of Set 2 | malangali
# Processing Record 19 of Set 2 | nauta
# Processing Record 20 of Set 2 | mezen
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | mpongwe
# Processing Record 23 of Set 2 | silifke
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | aykhal
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | khash
# Processing Record 29 of Set 2 | honiara
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | meulaboh
# Processing Record 33 of Set 2 | vaitape
# Processing Record 34 of Set 2 | townsville
# Processing Record 35 of Set 2 | constitucion
# Processing Record 36 of Set 2 | klaksvik
# Processing Record 37 of Set 2 | doka
# Processing Record 38 of Set 2 | kiruna
# Processing Record 39 of Set 2 | lagoa
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | touros
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | cayenne
# Processing Record 44 of Set 2 | bandarbeyla
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | manavgat
# Processing Record 47 of Set 2 | sakaiminato
# Processing Record 48 of Set 2 | andenes
# Processing Record 49 of Set 2 | labuhan
# Processing Record 50 of Set 2 | te anau
# Processing Record 1 of Set 3 | tambura
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | burriana
# Processing Record 5 of Set 3 | aklavik
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | grand gaube
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | kushmurun
# Processing Record 11 of Set 3 | grindavik
# Processing Record 12 of Set 3 | alaca
# Processing Record 13 of Set 3 | bathsheba
# Processing Record 14 of Set 3 | piacabucu
# Processing Record 15 of Set 3 | ostrovnoy
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | iqaluit
# Processing Record 18 of Set 3 | troy
# Processing Record 19 of Set 3 | sobolevo
# Processing Record 20 of Set 3 | tuatapere
# Processing Record 21 of Set 3 | adrar
# Processing Record 22 of Set 3 | mehamn
# Processing Record 23 of Set 3 | burica
# City not found. Skipping...
# Processing Record 24 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 3 | hutchinson
# Processing Record 26 of Set 3 | daxian
# City not found. Skipping...
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | vao
# Processing Record 30 of Set 3 | aksarka
# Processing Record 31 of Set 3 | akdepe
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | pizarro
# Processing Record 34 of Set 3 | weyburn
# Processing Record 35 of Set 3 | kannur
# Processing Record 36 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 3 | college
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | karanganom
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 3 | codrington
# Processing Record 44 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 3 | jucurutu
# Processing Record 46 of Set 3 | sakakah
# Processing Record 47 of Set 3 | altay
# Processing Record 48 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 49 of Set 3 | aboisso
# Processing Record 50 of Set 3 | xining
# Processing Record 1 of Set 4 | sangar
# Processing Record 2 of Set 4 | sur
# Processing Record 3 of Set 4 | youghal
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | calama
# Processing Record 6 of Set 4 | quesnel
# Processing Record 7 of Set 4 | katsuura
# Processing Record 8 of Set 4 | langham
# Processing Record 9 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | bambous virieux
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | taoudenni
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | sabang
# Processing Record 16 of Set 4 | kerema
# Processing Record 17 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 4 | talara
# Processing Record 19 of Set 4 | kamaishi
# Processing Record 20 of Set 4 | lukovetskiy
# Processing Record 21 of Set 4 | sumbe
# Processing Record 22 of Set 4 | pevek
# Processing Record 23 of Set 4 | lorengau
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | gimli
# Processing Record 26 of Set 4 | togur
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | san felipe
# Processing Record 29 of Set 4 | mitsamiouli
# Processing Record 30 of Set 4 | bourbonnais
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | husavik
# Processing Record 33 of Set 4 | kandrian
# Processing Record 34 of Set 4 | eyl
# Processing Record 35 of Set 4 | trincomalee
# Processing Record 36 of Set 4 | rochester
# Processing Record 37 of Set 4 | dondo
# Processing Record 38 of Set 4 | chirongui
# Processing Record 39 of Set 4 | tautira
# Processing Record 40 of Set 4 | mangan
# Processing Record 41 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 4 | lompoc
# Processing Record 43 of Set 4 | alice springs
# Processing Record 44 of Set 4 | castro
# Processing Record 45 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 46 of Set 4 | garowe
# Processing Record 47 of Set 4 | quatre cocos
# Processing Record 48 of Set 4 | ugoofaaru
# Processing Record 49 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 4 | caravelas
# Processing Record 1 of Set 5 | fortuna
# Processing Record 2 of Set 5 | nizhnevartovsk
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | pangody
# Processing Record 5 of Set 5 | cabra
# Processing Record 6 of Set 5 | flinders
# Processing Record 7 of Set 5 | tamale
# Processing Record 8 of Set 5 | kyabe
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | lavrentiya
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | lucapa
# Processing Record 13 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 15 of Set 5 | binzhou
# Processing Record 16 of Set 5 | bubaque
# Processing Record 17 of Set 5 | sivas
# Processing Record 18 of Set 5 | chuy
# Processing Record 19 of Set 5 | hay river
# Processing Record 20 of Set 5 | havre-saint-pierre
# Processing Record 21 of Set 5 | beyneu
# Processing Record 22 of Set 5 | dolores
# Processing Record 23 of Set 5 | deputatskiy
# Processing Record 24 of Set 5 | lebedinyy
# Processing Record 25 of Set 5 | coquimbo
# Processing Record 26 of Set 5 | pocri
# Processing Record 27 of Set 5 | koforidua
# Processing Record 28 of Set 5 | chokurdakh
# Processing Record 29 of Set 5 | tanete
# Processing Record 30 of Set 5 | port elizabeth
# Processing Record 31 of Set 5 | shuangyashan
# Processing Record 32 of Set 5 | cabo san lucas
# Processing Record 33 of Set 5 | cap malheureux
# Processing Record 34 of Set 5 | yabelo
# Processing Record 35 of Set 5 | buraydah
# Processing Record 36 of Set 5 | emerald
# Processing Record 37 of Set 5 | upernavik
# Processing Record 38 of Set 5 | khandbari
# Processing Record 39 of Set 5 | ixtapa
# Processing Record 40 of Set 5 | vestmanna
# Processing Record 41 of Set 5 | mahebourg
# Processing Record 42 of Set 5 | jamtara
# Processing Record 43 of Set 5 | ordzhonikidze
# Processing Record 44 of Set 5 | pulgaon
# Processing Record 45 of Set 5 | arys
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | torbay
# Processing Record 48 of Set 5 | faanui
# Processing Record 49 of Set 5 | coahuayana
# Processing Record 50 of Set 5 | saint-augustin
# Processing Record 1 of Set 6 | progreso
# Processing Record 2 of Set 6 | kasongo-lunda
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | ampanihy
# Processing Record 5 of Set 6 | luderitz
# Processing Record 6 of Set 6 | krasnoarmeysk
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | jablanica
# Processing Record 9 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 10 of Set 6 | shimoda
# Processing Record 11 of Set 6 | eskil
# Processing Record 12 of Set 6 | north platte
# Processing Record 13 of Set 6 | richards bay
# Processing Record 14 of Set 6 | hofn
# Processing Record 15 of Set 6 | dingle
# Processing Record 16 of Set 6 | tiksi
# Processing Record 17 of Set 6 | cairns
# Processing Record 18 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 6 | iisalmi
# Processing Record 20 of Set 6 | josanicka banja
# Processing Record 21 of Set 6 | pangnirtung
# Processing Record 22 of Set 6 | kankon
# Processing Record 23 of Set 6 | kapit
# Processing Record 24 of Set 6 | aripuana
# Processing Record 25 of Set 6 | killybegs
# Processing Record 26 of Set 6 | half moon bay
# Processing Record 27 of Set 6 | vostok
# Processing Record 28 of Set 6 | santa cruz de tenerife
# Processing Record 29 of Set 6 | saldanha
# Processing Record 30 of Set 6 | esperance
# Processing Record 31 of Set 6 | alofi
# Processing Record 32 of Set 6 | kidal
# Processing Record 33 of Set 6 | pasni
# Processing Record 34 of Set 6 | asau
# Processing Record 35 of Set 6 | konstantinovka
# Processing Record 36 of Set 6 | rio claro
# Processing Record 37 of Set 6 | bucerias
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | ilulissat
# Processing Record 40 of Set 6 | grand-santi
# Processing Record 41 of Set 6 | hashtrud
# Processing Record 42 of Set 6 | northam
# Processing Record 43 of Set 6 | tumba
# Processing Record 44 of Set 6 | airai
# Processing Record 45 of Set 6 | ocos
# Processing Record 46 of Set 6 | ayagoz
# Processing Record 47 of Set 6 | jalu
# Processing Record 48 of Set 6 | tutoia
# Processing Record 49 of Set 6 | ancud
# Processing Record 50 of Set 6 | gemena
# Processing Record 1 of Set 7 | anahuac
# Processing Record 2 of Set 7 | tougue
# Processing Record 3 of Set 7 | guilin
# Processing Record 4 of Set 7 | caucaia
# Processing Record 5 of Set 7 | leh
# Processing Record 6 of Set 7 | kati
# Processing Record 7 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 7 | kupang
# Processing Record 9 of Set 7 | svetlogorsk
# Processing Record 10 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | karpogory
# Processing Record 12 of Set 7 | tarancon
# Processing Record 13 of Set 7 | alyangula
# Processing Record 14 of Set 7 | pascagoula
# Processing Record 15 of Set 7 | umm lajj
# Processing Record 16 of Set 7 | san nicolas
# Processing Record 17 of Set 7 | kargil
# Processing Record 18 of Set 7 | yumen
# Processing Record 19 of Set 7 | tambo
# Processing Record 20 of Set 7 | bengkulu
# Processing Record 21 of Set 7 | lujan
# Processing Record 22 of Set 7 | venta
# Processing Record 23 of Set 7 | coos bay
# Processing Record 24 of Set 7 | iquique
# Processing Record 25 of Set 7 | mantua
# Processing Record 26 of Set 7 | batemans bay
# Processing Record 27 of Set 7 | kosa
# Processing Record 28 of Set 7 | nador
# Processing Record 29 of Set 7 | saint-joseph
# Processing Record 30 of Set 7 | tandalti
# Processing Record 31 of Set 7 | bajos de haina
# Processing Record 32 of Set 7 | biltine
# Processing Record 33 of Set 7 | sola
# Processing Record 34 of Set 7 | yangjiang
# Processing Record 35 of Set 7 | victoria
# Processing Record 36 of Set 7 | orlik
# Processing Record 37 of Set 7 | nanortalik
# Processing Record 38 of Set 7 | dzilam gonzalez
# Processing Record 39 of Set 7 | bethel
# Processing Record 40 of Set 7 | nizhniy odes
# Processing Record 41 of Set 7 | zhezkazgan
# Processing Record 42 of Set 7 | goedereede
# Processing Record 43 of Set 7 | coffs harbour
# Processing Record 44 of Set 7 | provideniya
# Processing Record 45 of Set 7 | hartford
# Processing Record 46 of Set 7 | ahipara
# Processing Record 47 of Set 7 | charters towers
# Processing Record 48 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 49 of Set 7 | lucatan
# City not found. Skipping...
# Processing Record 50 of Set 7 | skjervoy
# Processing Record 1 of Set 8 | kwinana
# Processing Record 2 of Set 8 | la ronge
# Processing Record 3 of Set 8 | palmer
# Processing Record 4 of Set 8 | tonj
# Processing Record 5 of Set 8 | hovd
# Processing Record 6 of Set 8 | axim
# Processing Record 7 of Set 8 | vardo
# Processing Record 8 of Set 8 | tilichiki
# Processing Record 9 of Set 8 | coruripe
# Processing Record 10 of Set 8 | barcelona
# Processing Record 11 of Set 8 | xiongzhou
# Processing Record 12 of Set 8 | qasigiannguit
# Processing Record 13 of Set 8 | manama
# Processing Record 14 of Set 8 | moscow
# Processing Record 15 of Set 8 | yamada
# Processing Record 16 of Set 8 | kachug
# Processing Record 17 of Set 8 | kyzyl
# Processing Record 18 of Set 8 | muros
# Processing Record 19 of Set 8 | haridwar
# Processing Record 20 of Set 8 | nieuw amsterdam
# Processing Record 21 of Set 8 | celestun
# Processing Record 22 of Set 8 | seoul
# Processing Record 23 of Set 8 | atar
# Processing Record 24 of Set 8 | bogorodskoye
# Processing Record 25 of Set 8 | wanning
# Processing Record 26 of Set 8 | mount gambier
# Processing Record 27 of Set 8 | cordoba
# Processing Record 28 of Set 8 | portland
# Processing Record 29 of Set 8 | alim
# Processing Record 30 of Set 8 | bendigo
# Processing Record 31 of Set 8 | lerwick
# Processing Record 32 of Set 8 | dawlatabad
# Processing Record 33 of Set 8 | taltal
# Processing Record 34 of Set 8 | ola
# Processing Record 35 of Set 8 | ye
# City not found. Skipping...
# Processing Record 36 of Set 8 | camacha
# Processing Record 37 of Set 8 | sitka
# Processing Record 38 of Set 8 | menongue
# Processing Record 39 of Set 8 | padang
# Processing Record 40 of Set 8 | ginir
# Processing Record 41 of Set 8 | pisco
# Processing Record 42 of Set 8 | bilibino
# Processing Record 43 of Set 8 | ous
# Processing Record 44 of Set 8 | antofagasta
# Processing Record 45 of Set 8 | boissevain
# Processing Record 46 of Set 8 | yerbogachen
# Processing Record 47 of Set 8 | black diamond
# Processing Record 48 of Set 8 | vanimo
# Processing Record 49 of Set 8 | kirakira
# Processing Record 50 of Set 8 | masallatah
# Processing Record 1 of Set 9 | komsomolskiy
# Processing Record 2 of Set 9 | sawakin
# Processing Record 3 of Set 9 | tucumcari
# Processing Record 4 of Set 9 | mandera
# Processing Record 5 of Set 9 | mormugao
# Processing Record 6 of Set 9 | gazanjyk
# Processing Record 7 of Set 9 | paysandu
# Processing Record 8 of Set 9 | kattivakkam
# Processing Record 9 of Set 9 | ketchikan
# Processing Record 10 of Set 9 | wilmington island
# Processing Record 11 of Set 9 | dunedin
# Processing Record 12 of Set 9 | bonfim
# Processing Record 13 of Set 9 | yeppoon
# Processing Record 14 of Set 9 | mokhsogollokh
# Processing Record 15 of Set 9 | schijndel
# Processing Record 16 of Set 9 | sorland
# Processing Record 17 of Set 9 | lugovskiy
# City not found. Skipping...
# Processing Record 18 of Set 9 | kahului
# Processing Record 19 of Set 9 | longyearbyen
# Processing Record 20 of Set 9 | broome
# Processing Record 21 of Set 9 | nantucket
# Processing Record 22 of Set 9 | minab
# Processing Record 23 of Set 9 | opuwo
# Processing Record 24 of Set 9 | ambulu
# Processing Record 25 of Set 9 | tura
# Processing Record 26 of Set 9 | gympie
# Processing Record 27 of Set 9 | port lincoln
# Processing Record 28 of Set 9 | christchurch
# Processing Record 29 of Set 9 | sechura
# Processing Record 30 of Set 9 | coihaique
# Processing Record 31 of Set 9 | sambava
# Processing Record 32 of Set 9 | ucluelet
# Processing Record 33 of Set 9 | rio gallegos
# Processing Record 34 of Set 9 | nouadhibou
# Processing Record 35 of Set 9 | luanda
# Processing Record 36 of Set 9 | qostanay
# Processing Record 37 of Set 9 | hobyo
# Processing Record 38 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 9 | liuzhou
# Processing Record 40 of Set 9 | buala
# Processing Record 41 of Set 9 | lao cai
# Processing Record 42 of Set 9 | margate
# Processing Record 43 of Set 9 | nikolayevka
# Processing Record 44 of Set 9 | santa cruz de la palma
# Processing Record 45 of Set 9 | iacu
# Processing Record 46 of Set 9 | sao jose da coroa grande
# Processing Record 47 of Set 9 | guerrero negro
# Processing Record 48 of Set 9 | canico
# Processing Record 49 of Set 9 | belaya kholunitsa
# Processing Record 50 of Set 9 | buguruslan
# Processing Record 1 of Set 10 | arman
# Processing Record 2 of Set 10 | akyab
# Processing Record 3 of Set 10 | masterton
# Processing Record 4 of Set 10 | gold coast
# Processing Record 5 of Set 10 | tazovskiy
# Processing Record 6 of Set 10 | cortland
# Processing Record 7 of Set 10 | teo
# Processing Record 8 of Set 10 | cao bang
# Processing Record 9 of Set 10 | khotyn
# Processing Record 10 of Set 10 | quelimane
# Processing Record 11 of Set 10 | santiago
# Processing Record 12 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 13 of Set 10 | manyana
# Processing Record 14 of Set 10 | kendal
# Processing Record 15 of Set 10 | karaidel
# Processing Record 16 of Set 10 | saint-malo
# Processing Record 17 of Set 10 | anshun
# Processing Record 18 of Set 10 | wasilla
# Processing Record 19 of Set 10 | vestmannaeyjar
# Processing Record 20 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 21 of Set 10 | krasnoselkup
# Processing Record 22 of Set 10 | poum
# Processing Record 23 of Set 10 | ha noi
# Processing Record 24 of Set 10 | hervey bay
# Processing Record 25 of Set 10 | trebinje
# Processing Record 26 of Set 10 | florianopolis
# Processing Record 27 of Set 10 | noyabrsk
# Processing Record 28 of Set 10 | cabedelo
# Processing Record 29 of Set 10 | shingu
# Processing Record 30 of Set 10 | soavinandriana
# Processing Record 31 of Set 10 | samarai
# Processing Record 32 of Set 10 | birin
# Processing Record 33 of Set 10 | tamasi
# Processing Record 34 of Set 10 | igarka
# Processing Record 35 of Set 10 | ulkan
# Processing Record 36 of Set 10 | mogadishu
# Processing Record 37 of Set 10 | surgut
# Processing Record 38 of Set 10 | abu dhabi
# Processing Record 39 of Set 10 | bracebridge
# Processing Record 40 of Set 10 | rio grande
# Processing Record 41 of Set 10 | nurobod
# Processing Record 42 of Set 10 | bac lieu
# Processing Record 43 of Set 10 | sao filipe
# Processing Record 44 of Set 10 | baykit
# Processing Record 45 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 46 of Set 10 | malyn
# Processing Record 47 of Set 10 | sapele
# Processing Record 48 of Set 10 | joppatowne
# Processing Record 49 of Set 10 | biak
# Processing Record 50 of Set 10 | chifeng
# Processing Record 1 of Set 11 | beipiao
# Processing Record 2 of Set 11 | bolshaya atnya
# City not found. Skipping...
# Processing Record 3 of Set 11 | didao
# Processing Record 4 of Set 11 | alvorada
# Processing Record 5 of Set 11 | tshikapa
# Processing Record 6 of Set 11 | lakes entrance
# Processing Record 7 of Set 11 | saint-pierre
# Processing Record 8 of Set 11 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 9 of Set 11 | fairbanks
# Processing Record 10 of Set 11 | bay roberts
# Processing Record 11 of Set 11 | mbigou
# Processing Record 12 of Set 11 | bairiki
# Processing Record 13 of Set 11 | moerai
# Processing Record 14 of Set 11 | viedma
# Processing Record 15 of Set 11 | hanyang
# Processing Record 16 of Set 11 | fort-shevchenko
# Processing Record 17 of Set 11 | issaquah
# Processing Record 18 of Set 11 | mattru
# Processing Record 19 of Set 11 | bima
# Processing Record 20 of Set 11 | udachnyy
# Processing Record 21 of Set 11 | aksu
# Processing Record 22 of Set 11 | isabela
# Processing Record 23 of Set 11 | cacequi
# Processing Record 24 of Set 11 | luau
# Processing Record 25 of Set 11 | lahij
# Processing Record 26 of Set 11 | ilhabela
# Processing Record 27 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 11 | warrnambool
# Processing Record 29 of Set 11 | vila franca do campo
# Processing Record 30 of Set 11 | stromness
# Processing Record 31 of Set 11 | mwense
# Processing Record 32 of Set 11 | makakilo city
# Processing Record 33 of Set 11 | maniitsoq
# Processing Record 34 of Set 11 | lillers
# Processing Record 35 of Set 11 | port macquarie
# Processing Record 36 of Set 11 | luwuk
# Processing Record 37 of Set 11 | kieta
# Processing Record 38 of Set 11 | mazsalaca
# Processing Record 39 of Set 11 | atambua
# Processing Record 40 of Set 11 | nyurba
# Processing Record 41 of Set 11 | kununurra
# Processing Record 42 of Set 11 | wewak
# Processing Record 43 of Set 11 | kungurtug
# Processing Record 44 of Set 11 | pirapozinho
# Processing Record 45 of Set 11 | assiniboia
# Processing Record 46 of Set 11 | newport
# Processing Record 47 of Set 11 | ulladulla
# Processing Record 48 of Set 11 | guozhen
# Processing Record 49 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 11 | kaya
# Processing Record 1 of Set 12 | manokwari
# Processing Record 2 of Set 12 | beloha
# Processing Record 3 of Set 12 | necochea
# Processing Record 4 of Set 12 | okhotsk
# Processing Record 5 of Set 12 | kurmanayevka
# Processing Record 6 of Set 12 | santa cruz
# Processing Record 7 of Set 12 | puerto del rosario
# Processing Record 8 of Set 12 | puerto leguizamo
# Processing Record 9 of Set 12 | springfield
# Processing Record 10 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 12 | kavieng
# Processing Record 12 of Set 12 | broken hill
# Processing Record 13 of Set 12 | gat
# Processing Record 14 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 12 | gizo
# Processing Record 16 of Set 12 | solnechnyy
# Processing Record 17 of Set 12 | severo-yeniseyskiy
# Processing Record 18 of Set 12 | mahajanga
# Processing Record 19 of Set 12 | wangqing
# Processing Record 20 of Set 12 | yulara
# Processing Record 21 of Set 12 | griffith
# Processing Record 22 of Set 12 | cockburn town
# Processing Record 23 of Set 12 | pringsewu
# Processing Record 24 of Set 12 | san luis
# Processing Record 25 of Set 12 | mayor pablo lagerenza
# Processing Record 26 of Set 12 | cozumel
# Processing Record 27 of Set 12 | berezovyy
# Processing Record 28 of Set 12 | kloulklubed
# Processing Record 29 of Set 12 | goderich
# Processing Record 30 of Set 12 | inhambane
# Processing Record 31 of Set 12 | ahuimanu
# Processing Record 32 of Set 12 | kiama
# Processing Record 33 of Set 12 | sioux falls
# Processing Record 34 of Set 12 | dandeli
# Processing Record 35 of Set 12 | mount isa
# Processing Record 36 of Set 12 | lanzhou
# Processing Record 37 of Set 12 | korla
# Processing Record 38 of Set 12 | havoysund
# Processing Record 39 of Set 12 | frohnleiten
# Processing Record 40 of Set 12 | turukhansk
# Processing Record 41 of Set 12 | choma
# Processing Record 42 of Set 12 | rovaniemi
# Processing Record 43 of Set 12 | ismailia
# Processing Record 44 of Set 12 | hasaki
# Processing Record 45 of Set 12 | shache
# Processing Record 46 of Set 12 | mareeba
# Processing Record 47 of Set 12 | comodoro rivadavia
# Processing Record 48 of Set 12 | qandala
# Processing Record 49 of Set 12 | lodja
# Processing Record 50 of Set 12 | aransas pass
# Processing Record 1 of Set 13 | urdoma
# Processing Record 2 of Set 13 | harper
# Processing Record 3 of Set 13 | bardiyah
# Processing Record 4 of Set 13 | sao lourenco do sul
# Processing Record 5 of Set 13 | erzin
# Processing Record 6 of Set 13 | fort nelson
# Processing Record 7 of Set 13 | naliya
# Processing Record 8 of Set 13 | krasnyy chikoy
# Processing Record 9 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 13 | mikhaylovka
# Processing Record 11 of Set 13 | hami
# Processing Record 12 of Set 13 | iberia
# Processing Record 13 of Set 13 | pidvynohradiv
# Processing Record 14 of Set 13 | oktyabrskoye
# Processing Record 15 of Set 13 | derzhavinsk
# Processing Record 16 of Set 13 | zhengjiatun
# Processing Record 17 of Set 13 | dillon
# Processing Record 18 of Set 13 | eyrarbakki
# Processing Record 19 of Set 13 | nuevo laredo
# Processing Record 20 of Set 13 | benin
# Processing Record 21 of Set 13 | paamiut
# Processing Record 22 of Set 13 | araouane
# Processing Record 23 of Set 13 | port moresby
# Processing Record 24 of Set 13 | namibe
# Processing Record 25 of Set 13 | carutapera
# Processing Record 26 of Set 13 | alta floresta
# Processing Record 27 of Set 13 | nizwa
# Processing Record 28 of Set 13 | tete
# Processing Record 29 of Set 13 | oranjestad
# Processing Record 30 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 13 | valparaiso
# Processing Record 32 of Set 13 | ariquemes
# Processing Record 33 of Set 13 | mwaya
# Processing Record 34 of Set 13 | callaway
# Processing Record 35 of Set 13 | winnemucca
# Processing Record 36 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 13 | belen
# Processing Record 38 of Set 13 | mayo
# Processing Record 39 of Set 13 | georgiyevka
# Processing Record 40 of Set 13 | kutum
# Processing Record 41 of Set 13 | banda aceh
# Processing Record 42 of Set 13 | monte alegre
# Processing Record 43 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 13 | karratha
# Processing Record 45 of Set 13 | miranda
# Processing Record 46 of Set 13 | kushima
# Processing Record 47 of Set 13 | liverpool
# Processing Record 48 of Set 13 | martapura
# Processing Record 49 of Set 13 | wagar
# Processing Record 50 of Set 13 | beya
# Processing Record 1 of Set 14 | dabakala
# Processing Record 2 of Set 14 | diffa
# Processing Record 3 of Set 14 | poopo
# Processing Record 4 of Set 14 | shaoyang
# Processing Record 5 of Set 14 | baglan
# Processing Record 6 of Set 14 | gornyy
# Processing Record 7 of Set 14 | lata
# Processing Record 8 of Set 14 | uvira
# Processing Record 9 of Set 14 | oyama
# Processing Record 10 of Set 14 | gdansk
# Processing Record 11 of Set 14 | beringovskiy
# Processing Record 12 of Set 14 | san quintin
# Processing Record 13 of Set 14 | itoman
# Processing Record 14 of Set 14 | camabatela
# Processing Record 15 of Set 14 | san vicente de canete
# Processing Record 16 of Set 14 | lincoln
# Processing Record 17 of Set 14 | yala
# Processing Record 18 of Set 14 | rocha
# Processing Record 19 of Set 14 | greytown
# Processing Record 20 of Set 14 | plettenberg bay
# Processing Record 21 of Set 14 | klamath falls
# Processing Record 22 of Set 14 | belaya gora
# Processing Record 23 of Set 14 | namie
# Processing Record 24 of Set 14 | halle
# Processing Record 25 of Set 14 | port keats
# Processing Record 26 of Set 14 | rincon
# Processing Record 27 of Set 14 | kendari
# Processing Record 28 of Set 14 | presidente epitacio
# Processing Record 29 of Set 14 | severnyy-kospashskiy
# Processing Record 30 of Set 14 | tamandare
# Processing Record 31 of Set 14 | casablanca
# Processing Record 32 of Set 14 | gurjaani
# Processing Record 33 of Set 14 | lander
# Processing Record 34 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 14 | batsfjord
# Processing Record 36 of Set 14 | warri
# Processing Record 37 of Set 14 | chapais
# Processing Record 38 of Set 14 | weatherford
# Processing Record 39 of Set 14 | limoges
# Processing Record 40 of Set 14 | valdemarpils
# Processing Record 41 of Set 14 | stolin
# Processing Record 42 of Set 14 | kosh-agach
# Processing Record 43 of Set 14 | nakamura
# Processing Record 44 of Set 14 | olafsvik
# Processing Record 45 of Set 14 | albacete
# Processing Record 46 of Set 14 | awbari
# Processing Record 47 of Set 14 | huarmey
# Processing Record 48 of Set 14 | vavuniya
# Processing Record 49 of Set 14 | marawi
# Processing Record 50 of Set 14 | hambantota
# Processing Record 1 of Set 15 | kaitong
# Processing Record 2 of Set 15 | ligayan
# Processing Record 3 of Set 15 | wittingen
# Processing Record 4 of Set 15 | auki
# Processing Record 5 of Set 15 | sao bento do sul
# Processing Record 6 of Set 15 | ghanzi
# Processing Record 7 of Set 15 | barguzin
# Processing Record 8 of Set 15 | estelle
# Processing Record 9 of Set 15 | tateyama
# Processing Record 10 of Set 15 | iwanai
# Processing Record 11 of Set 15 | kindersley
# Processing Record 12 of Set 15 | basavakalyan
# Processing Record 13 of Set 15 | muroto
# Processing Record 14 of Set 15 | khuzdar
# Processing Record 15 of Set 15 | millau
# Processing Record 16 of Set 15 | lazaro cardenas
# Processing Record 17 of Set 15 | marolambo
# Processing Record 18 of Set 15 | robertsganj
# Processing Record 19 of Set 15 | zarnesti
# Processing Record 20 of Set 15 | tupik
# Processing Record 21 of Set 15 | kerman
# Processing Record 22 of Set 15 | vila velha
# Processing Record 23 of Set 15 | tocoa
# Processing Record 24 of Set 15 | porbandar
# Processing Record 25 of Set 15 | santa rosa
# Processing Record 26 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 27 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 15 | rong kwang
# Processing Record 29 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 15 | nizhniy kuranakh
# Processing Record 31 of Set 15 | khani
# Processing Record 32 of Set 15 | saint-francois
# Processing Record 33 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 15 | payo
# Processing Record 35 of Set 15 | ponta delgada
# Processing Record 36 of Set 15 | sandominic
# Processing Record 37 of Set 15 | sulangan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Mataura -46.1927  168.8643     50.49        98          78
# 1           Rikitea -23.1203 -134.9692     76.73        77          49
# 2    Severo-Kurilsk  50.6789  156.1250     38.71        95         100
# 3      Saint George  37.1041 -113.5841     80.64        12           0
# 4     Sioux Lookout  50.1001  -91.9170     44.67       100         100
# ..              ...      ...       ...       ...       ...         ...
# 677  Saint-Francois  46.4154    3.9054     72.84        35           0
# 678            Payo  -3.7508  103.6372     74.91        84          98
# 679   Ponta Delgada  37.7333  -25.6667     68.72        68          40
# 680      Sandominic  46.5840   25.7803     48.97        94         100
# 681        Sulangan  11.1373  123.7228     82.58        75          66
#
#      Wind Speed Country Current Description
# 0          1.99      NZ       broken clouds
# 1         23.15      PF    scattered clouds
# 2         19.15      RU          light rain
# 3          8.01      US           clear sky
# 4         10.36      CA          light rain
# ..          ...     ...                 ...
# 677       10.36      FR           clear sky
# 678        2.04      ID     overcast clouds
# 679       11.50      PT    scattered clouds
# 680        3.36      RO     overcast clouds
# 681       15.97      PH       broken clouds
#
# [682 rows x 9 columns]

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Mataura      NZ -46.1927  168.8643     50.49        98
# 1           Rikitea      PF -23.1203 -134.9692     76.73        77
# 2    Severo-Kurilsk      RU  50.6789  156.1250     38.71        95
# 3      Saint George      US  37.1041 -113.5841     80.64        12
# 4     Sioux Lookout      CA  50.1001  -91.9170     44.67       100
# ..              ...     ...      ...       ...       ...       ...
# 677  Saint-Francois      FR  46.4154    3.9054     72.84        35
# 678            Payo      ID  -3.7508  103.6372     74.91        84
# 679   Ponta Delgada      PT  37.7333  -25.6667     68.72        68
# 680      Sandominic      RO  46.5840   25.7803     48.97        94
# 681        Sulangan      PH  11.1373  123.7228     82.58        75
#
#      Cloudiness  Wind Speed Current Description
# 0            78        1.99       broken clouds
# 1            49       23.15    scattered clouds
# 2           100       19.15          light rain
# 3             0        8.01           clear sky
# 4           100       10.36          light rain
# ..          ...         ...                 ...
# 677           0       10.36           clear sky
# 678          98        2.04     overcast clouds
# 679          40       11.50    scattered clouds
# 680         100        3.36     overcast clouds
# 681          66       15.97       broken clouds
#
# [682 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
